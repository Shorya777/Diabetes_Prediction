# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('pima-data.csv')
# df.isnull().sum()
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# ..        ...           ...           ...        ...      ...   ...
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age    skin  diabetes
# 0        0.627   50  1.3790      True
# 1        0.351   31  1.1426     False
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['diabetes'] = le.fit_transform(df['diabetes'])
df.drop('skin', axis=1,inplace= True) #skin and thickness has strong correlation
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# ..        ...           ...           ...        ...      ...   ...
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age  diabetes
# 0        0.627   50         1
# 1        0.351   31         0
# 2        0.672   32         1
# ...

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#               num_preg  glucose_conc  diastolic_bp  thickness   insulin  \
# num_preg      1.000000      0.129459      0.141282  -0.081672 -0.073535
# glucose_conc  0.129459      1.000000      0.152590   0.057328  0.331357
# diastolic_bp  0.141282      0.152590      1.000000   0.207371  0.088933
# thickness    -0.081672      0.057328      0.207371   1.000000  0.436783
# insulin      -0.073535      0.331357      0.088933   0.436783  1.000000
# bmi           0.017683      0.221071      0.281805   0.392573  0.197859
# diab_pred    -0.033523      0.137337      0.041265   0.183928  0.185071
# age           0.544341      0.263514      0.239528  -0.113970 -0.042163
# diabetes      0.221898      0.466581      0.065068   0.074752  0.130548
#
#                    bmi  diab_pred       age  diabetes
# num_preg      0.017683  -0.033523  0.544341  0.221898
# glucose_conc  0.221071   0.137337  0.263514  0.466581
# diastolic_bp  0.281805   0.041265  0.239528  0.065068
# ...

# %%
from sklearn.preprocessing import StandardScaler

diabetes = df['diabetes'].values.reshape(-1,1)

scale = StandardScaler()
to_scale = df.iloc[:, :-1]
scaled_data = scale.fit_transform(to_scale)
df = pd.DataFrame(scaled_data)

columns = ['num_preg', 'glucose_conc' , 'diastolic_bp', 'thickness' ,'insulin', 'bmi', 'dia_pred' , 'age']
df.columns = columns
df['diabetes'] = diabetes

df
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness   insulin       bmi  \
# 0    0.639947      0.848324      0.149641   0.907270 -0.692891  0.204013
# 1   -0.844885     -1.123396     -0.160546   0.530902 -0.692891 -0.684422
# 2    1.233880      1.943724     -0.263941  -1.288212 -0.692891 -1.103255
# 3   -0.844885     -0.998208     -0.160546   0.154533  0.123302 -0.494043
# 4   -1.141852      0.504055     -1.504687   0.907270  0.765836  1.409746
# ..        ...           ...           ...        ...       ...       ...
# 763  1.827813     -0.622642      0.356432   1.722735  0.870031  0.115169
# 764 -0.547919      0.034598      0.046245   0.405445 -0.692891  0.610154
# 765  0.342981      0.003301      0.149641   0.154533  0.279594 -0.735190
# 766 -0.844885      0.159787     -0.470732  -1.288212 -0.692891 -0.240205
# 767 -0.844885     -0.873019      0.046245   0.656358 -0.692891 -0.202129
#
#      dia_pred       age  diabetes
# 0    0.468492  1.425995         1
# ...

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, :-1]
Y = df['diabetes']
x_train , x_test , y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state =42)

# from sklearn.model_selection import StratifiedShuffleSplit

# split = StratifiedShuffleSplit(n_splits = 1 , test_size = 0.2, random_state = 42)
# for train_index , test_index in split.split(df , df['diabetes']):
#     strat_train  =df.loc[train_index]
#     strat_test = df.loc[test_index]
# x_train = strat_train.drop('diabetes', axis = 1)
# y_train  = strat_train['diabetes'].copy()

# x_test = strat_test.drop('diabetes', axis = 1)
# y_test  = strat_test['diabetes'].copy()

x_train.reset_index(drop = True ,inplace = True)
y_train.reset_index(drop = True, inplace = True)
x_test.reset_index(drop = True ,inplace = True)
y_test.reset_index(drop = True, inplace = True)

# diabetes_true_count = len(y_train.loc[y_train == True])
# diabetes_false_count = len(y_train.loc[y_train == False])
# print(diabetes_true_count)
# print(diabetes_false_count)

# diabetes_true_count_test = len(y_test.loc[y_train == True])
# diabetes_false_count_test = len(y_test.loc[y_train == False])
# print(diabetes_true_count_test)
# print(diabetes_false_count_test)

print(len(y_train.loc[y_train == 1]))
print(len(y_train.loc[y_train == 0]))
print(len(y_test.loc[y_test== 1]))
print(len(y_test.loc[y_test== 0]))
# Out:
# 213
# 401
# 55
# 99

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()
lr.fit(x_train , y_train)
y_pred = lr.predict(x_test)
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.7532467532467533

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion = 'gini' ,min_samples_split=3, max_depth = 5,random_state =0)
tree.fit(x_train , y_train)
y_pred = tree.predict(x_test) 
acc = accuracy_score(y_test , y_pred)
acc
# Out:
# 0.7987012987012987

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=5, min_samples_split=15 ,random_state =0)
# rf = RandomForestClassifier()
rf.fit(x_train,y_train) 
y_pred = rf.predict(x_test)
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.7662337662337663

# %%
from sklearn.svm import SVC

svc = SVC(kernel = 'linear')
svc.fit(x_train,y_train)
y_pred = svc.predict(x_test)
acc = accuracy_score(y_test , y_pred)
acc
# Out:
# 0.7597402597402597

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(metric= 'minkowski' ,n_neighbors =20)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7597402597402597
